# %%
import pandas as pd
import numpy as np

# %% [markdown]
# read csv

# %%
df = pd.read_csv('..\\data\\sound_track_imdb_top_250_movie_tv_series.csv', delimiter=",", index_col=0)

# %%
df.columns
# Out:
# Index(['name', 'year', 'song_name', 'written_by', 'performed_by',
#        'composed_by', 'lyrics_by', 'written_performed_by', 'music_by',
#        'courtesy_of', 'conducted_by', 'libretto_by', 'under_license_from'],
#       dtype='object')

# %% [markdown]
# select the needed columns and create new df

# %%
df_selected = df.loc[:,['name','year','song_name','performed_by']]
df_selected
# Out:
#                           name  year  \
# 0     The Shawshank Redemption  1994
# 1     The Shawshank Redemption  1994
# 2     The Shawshank Redemption  1994
# 3     The Shawshank Redemption  1994
# 4     The Shawshank Redemption  1994
# ...                        ...   ...
# 3128      Love, Death & Robots  2019
# 3129               Foyle's War  2002
# 3130         Jesus of Nazareth  1977
# 3131                    Luther  2010
# 3132                     Ethos  2020
#
#                                               song_name  \
# 0                                     If I Didn't Care
# 1                                 Duettino - Sull'aria
# 2                                Put The Blame On Mame
# 3                                       Lovesick Blues
# 4                             Willie and The Hand Jive
# ...                                                 ...
# 3128  It looks like we don't have any Soundtracks fo...
# 3129  It looks like we don't have any Soundtracks fo...
# 3130  It looks like we don't have any Soundtracks fo...
# 3131                                   Paradise Circus
# 3132  It looks like we don't have any Soundtracks fo...
#
#                                            performed_by
# 0                                        The Ink Spots
# 1     Edith Mathis (uncredited) and Gundula Janowitz...
# 2                                                   NaN
# 3                                        Hank Williams
# 4                                                   NaN
# ...                                                 ...
# 3128                                                NaN
# 3129                                                NaN
# 3130                                                NaN
# 3131                                     Massive Attack
# 3132                                                NaN
#
# [3133 rows x 4 columns]

# %%
# df_selected['performed_by'].isna().sum()

# %%
# filter_mask = df_selected['song_name'] == "It looks like we don't have any Soundtracks for this title yet."
# filter_mask.sum()

# %%
# df_selected[filter_mask]

# %% [markdown]
# replace "it looks like we don't ...." with NaN

# %%
df_selected.replace("It looks like we don't have any Soundtracks for this title yet.", "Not available", inplace=True)

# %% [markdown]
# write df_selected to csv file

# %%
# df_selected.to_csv("..\\data\\filtered_movie_songs.csv")

# %%
df_selected.groupby('song_name').count()
# Out:
#                                                     name  year  performed_by
# song_name
# 'Andante' from 'Sonata No. 1 In G Major, BWV 10...     1     1             1
# 'Branded' Theme Song                                   1     1             0
# 'Summertime' from 'Porgy and Bess'                     1     1             0
# 'The Itchy & Scratchy Show' Theme                      1     1             1
# 'Variatio 25' of 'The Goldberg Variations'             1     1             1
# ...                                                  ...   ...           ...
# Ça Plane Pour Moi                                      1     1             1
# École Buissonnière                                     1     1             0
# Étude Op. 25, No. 11 in A minor ('Winter Wind')        1     1             0
# Ê Baiana                                               1     1             1
# Ödet Är en Rackare                                     1     1             0
#
# [2787 rows x 3 columns]

# %% [markdown]
# find duplicate songs

# %%
duplicates = df_selected['song_name'].duplicated(keep=False)
duplicate_songs_df = df_selected[duplicates]
duplicate_songs_df = duplicate_songs_df.sort_values(by='song_name')
duplicate_songs_df
# Out:
#                                      name  year  \
# 526                        Apocalypse Now  1979
# 1468                               Casino  1995
# 1517                               Casino  1995
# 654                       American Beauty  1999
# 106                          Forrest Gump  1994
# ...                                   ...   ...
# 752                             Toy Story  1995
# 1680               No Country for Old Men  2007
# 2679                       True Detective  2014
# 2172                         Mary and Max  2009
# 1783  Lock, Stock and Two Smoking Barrels  1998
#
#                            song_name                      performed_by
# 526   (I Can't Get No) Satisfaction                The Rolling Stones
# 1468  (I Can't Get No) Satisfaction                The Rolling Stones
# 1517  (I Can't Get No) Satisfaction                              Devo
# 654        All Along The Watchtower                                NaN
# 106        All Along The Watchtower       The Jimi Hendrix Experience
# ...                              ...                               ...
# 752       You've Got a Friend in Me        Randy Newman & Lyle Lovett
# 1680                 Young Men Dead                  The Black Angels
# 2679                 Young Men Dead                                NaN
# 2172                  Zorba's Dance         The London Pops Orchestra
# 1783                  Zorba's Dance   David A. Hughes and John Murphy
#
# [460 rows x 4 columns]

# %%
df[df['conducted_by'].notnull()].isna().sum()

# df.notna().sum()
# Out:
# name                      0
# year                      0
# song_name                 0
# written_by               74
# performed_by              9
# composed_by              92
# lyrics_by               105
# written_performed_by    107
# music_by                 70
# courtesy_of              62
# conducted_by              0
# libretto_by             100
# under_license_from      102
# dtype: int64
